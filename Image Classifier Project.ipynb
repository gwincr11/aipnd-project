# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
import torch
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np
import json
from torch import nn
from torch import optim
import torch.nn.functional as F
from collections import OrderedDict
weights = models.VGG19_Weights.DEFAULT

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

preprocess = weights.transforms()

training_transforms = transforms.Compose([transforms.RandomRotation(30),
                                          transforms.Resize(256),
                                          transforms.RandomResizedCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                               [0.229, 0.224, 0.225])
                                          ])
print(preprocess)

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform=training_transforms)

test_data = datasets.ImageFolder(test_dir, transform=preprocess)

valid_data = datasets.ImageFolder(valid_dir, transform=preprocess)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloaders = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data, batch_size=32, shuffle=True)
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

images, labels = next(iter(trainloaders))
imshow(images[0], normalize=True)
print(labels)
# Out:
# tensor([ 52,  82,  64,  22,  43,  87,  48,  67, 101,  48,  52,  15,  77,  97,
#          14,   7,  11,  76,  55,  90,  59,  92,  41,  40,   8,   5,  40,  15,
#          73,  67,  95,   8])

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
model = models.vgg19(weights=weights)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
def classifier():
    return nn.Sequential(
        OrderedDict([
            ('fc1',     nn.Linear(25088, 4096)),
            ('relu',    nn.ReLU()),
            ('dropout', nn.Dropout(p=0.2, inplace=False)),
            ('fc2',     nn.Linear(4096, 2048)),
            ('relu2',   nn.ReLU()),
            ('dropout2',nn.Dropout(p=0.5, inplace=False)),
            ('fc3',  nn.Linear(2048, 102)),
            ('output', nn.LogSoftmax(dim=1))
        ]))

# %%
for param in model.parameters():
    param.requires_grad = False
    
model.classifier = classifier()

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
def validate_model(model, criterion, dataloader, device):
    model.eval()
    model.to(device=device)
    
    accuracy, test_loss = 0, 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        
        output = model.forward(inputs)
        test_loss += criterion(output, labels).item()
        
        ps = torch.exp(output)
        top_p, top_class = ps.topk(1, dim=1)
        equals = top_class == labels.view(*top_class.shape)
        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
        
    return test_loss/len(dataloader), accuracy/len(dataloader)

# %%
# TODO: Do validation on the test set
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

criterion = nn.NLLLoss()
# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
model.to(device)
running_loss = 0
epochs = 10
print_every = 10

for epoch in range(epochs):
    for ii, (inputs, labels) in enumerate(trainloaders):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        if ii % print_every == 0:
            loss, accuracy = validate_model(model=model, criterion=criterion, dataloader=validloader, device=device)
            print("Epoch: {}/{} ".format(epoch+1, epochs),
                  "Training Loss: {:.3f} ".format(running_loss/print_every),
                  "Validation Loss: {:.3f} ".format(loss),
                  "Validation Accuracy: {:.3f}".format(accuracy))
            running_loss = 0
            model.train()
# Out:
# Epoch: 1/10  Training Loss: 0.465  Validation Loss: 8.953  Validation Accuracy: 0.019
# Epoch: 1/10  Training Loss: 5.725  Validation Loss: 4.452  Validation Accuracy: 0.054
# Epoch: 1/10  Training Loss: 4.458  Validation Loss: 4.186  Validation Accuracy: 0.111
# Epoch: 1/10  Training Loss: 4.263  Validation Loss: 3.909  Validation Accuracy: 0.164
# Epoch: 1/10  Training Loss: 3.996  Validation Loss: 3.670  Validation Accuracy: 0.191
# Epoch: 1/10  Training Loss: 3.775  Validation Loss: 3.416  Validation Accuracy: 0.214
# Epoch: 1/10  Training Loss: 3.477  Validation Loss: 3.125  Validation Accuracy: 0.264
# Epoch: 1/10  Training Loss: 3.409  Validation Loss: 2.779  Validation Accuracy: 0.300
# Epoch: 1/10  Training Loss: 3.212  Validation Loss: 2.632  Validation Accuracy: 0.337
# Epoch: 1/10  Training Loss: 2.813  Validation Loss: 2.574  Validation Accuracy: 0.320
# Epoch: 1/10  Training Loss: 2.837  Validation Loss: 2.222  Validation Accuracy: 0.413
# Epoch: 1/10  Training Loss: 2.644  Validation Loss: 2.063  Validation Accuracy: 0.464
# Epoch: 1/10  Training Loss: 2.848  Validation Loss: 1.928  Validation Accuracy: 0.474
# Epoch: 1/10  Training Loss: 2.589  Validation Loss: 1.872  Validation Accuracy: 0.506
# Epoch: 1/10  Training Loss: 2.549  Validation Loss: 1.819  Validation Accuracy: 0.489
# Epoch: 1/10  Training Loss: 2.609  Validation Loss: 1.828  Validation Accuracy: 0.498
# Epoch: 1/10  Training Loss: 2.199  Validation Loss: 1.651  Validation Accuracy: 0.545
# Epoch: 1/10  Training Loss: 2.566  Validation Loss: 1.735  Validation Accuracy: 0.521
# Epoch: 1/10  Training Loss: 2.413  Validation Loss: 1.555  Validation Accuracy: 0.575
# Epoch: 1/10  Training Loss: 2.413  Validation Loss: 1.442  Validation Accuracy: 0.617
# Epoch: 1/10  Training Loss: 2.307  Validation Loss: 1.442  Validation Accuracy: 0.613
# Epoch: 2/10  Training Loss: 1.098  Validation Loss: 1.604  Validation Accuracy: 0.566
# Epoch: 2/10  Training Loss: 1.992  Validation Loss: 1.425  Validation Accuracy: 0.617
# Epoch: 2/10  Training Loss: 2.103  Validation Loss: 1.299  Validation Accuracy: 0.643
# Epoch: 2/10  Training Loss: 2.013  Validation Loss: 1.396  Validation Accuracy: 0.614
# Epoch: 2/10  Training Loss: 2.056  Validation Loss: 1.269  Validation Accuracy: 0.632
# Epoch: 2/10  Training Loss: 1.979  Validation Loss: 1.325  Validation Accuracy: 0.602
# Epoch: 2/10  Training Loss: 2.107  Validation Loss: 1.292  Validation Accuracy: 0.640
# Epoch: 2/10  Training Loss: 1.966  Validation Loss: 1.248  Validation Accuracy: 0.653
# Epoch: 2/10  Training Loss: 1.930  Validation Loss: 1.323  Validation Accuracy: 0.621
# Epoch: 2/10  Training Loss: 1.910  Validation Loss: 1.253  Validation Accuracy: 0.648
# Epoch: 2/10  Training Loss: 1.758  Validation Loss: 1.155  Validation Accuracy: 0.674
# Epoch: 2/10  Training Loss: 2.032  Validation Loss: 1.161  Validation Accuracy: 0.675
# Epoch: 2/10  Training Loss: 1.668  Validation Loss: 1.243  Validation Accuracy: 0.648
# Epoch: 2/10  Training Loss: 2.102  Validation Loss: 1.097  Validation Accuracy: 0.695
# Epoch: 2/10  Training Loss: 1.882  Validation Loss: 1.187  Validation Accuracy: 0.693
# Epoch: 2/10  Training Loss: 1.995  Validation Loss: 1.168  Validation Accuracy: 0.685
# Epoch: 2/10  Training Loss: 1.959  Validation Loss: 1.161  Validation Accuracy: 0.695
# Epoch: 2/10  Training Loss: 1.848  Validation Loss: 1.110  Validation Accuracy: 0.701
# Epoch: 2/10  Training Loss: 1.915  Validation Loss: 1.071  Validation Accuracy: 0.707
# Epoch: 2/10  Training Loss: 1.866  Validation Loss: 1.109  Validation Accuracy: 0.689
# Epoch: 2/10  Training Loss: 1.887  Validation Loss: 1.187  Validation Accuracy: 0.672
# Epoch: 3/10  Training Loss: 0.954  Validation Loss: 1.162  Validation Accuracy: 0.696
# Epoch: 3/10  Training Loss: 1.744  Validation Loss: 1.238  Validation Accuracy: 0.672
# Epoch: 3/10  Training Loss: 2.001  Validation Loss: 1.101  Validation Accuracy: 0.709
# Epoch: 3/10  Training Loss: 1.733  Validation Loss: 1.115  Validation Accuracy: 0.714
# Epoch: 3/10  Training Loss: 1.824  Validation Loss: 1.028  Validation Accuracy: 0.731
# Epoch: 3/10  Training Loss: 1.707  Validation Loss: 1.038  Validation Accuracy: 0.721
# Epoch: 3/10  Training Loss: 1.489  Validation Loss: 0.977  Validation Accuracy: 0.726
# Epoch: 3/10  Training Loss: 1.604  Validation Loss: 0.940  Validation Accuracy: 0.749
# Epoch: 3/10  Training Loss: 1.788  Validation Loss: 1.043  Validation Accuracy: 0.735
# Epoch: 3/10  Training Loss: 2.100  Validation Loss: 1.202  Validation Accuracy: 0.685
# Epoch: 3/10  Training Loss: 1.900  Validation Loss: 0.909  Validation Accuracy: 0.760
# Epoch: 3/10  Training Loss: 1.744  Validation Loss: 1.029  Validation Accuracy: 0.721
# Epoch: 3/10  Training Loss: 1.861  Validation Loss: 0.922  Validation Accuracy: 0.753
# Epoch: 3/10  Training Loss: 1.677  Validation Loss: 0.905  Validation Accuracy: 0.759
# Epoch: 3/10  Training Loss: 1.816  Validation Loss: 0.913  Validation Accuracy: 0.752
# Epoch: 3/10  Training Loss: 1.651  Validation Loss: 0.994  Validation Accuracy: 0.725
# Epoch: 3/10  Training Loss: 1.665  Validation Loss: 0.977  Validation Accuracy: 0.738
# Epoch: 3/10  Training Loss: 1.961  Validation Loss: 1.036  Validation Accuracy: 0.732
# Epoch: 3/10  Training Loss: 1.652  Validation Loss: 1.026  Validation Accuracy: 0.735
# Epoch: 3/10  Training Loss: 1.748  Validation Loss: 0.887  Validation Accuracy: 0.762
# Epoch: 3/10  Training Loss: 1.755  Validation Loss: 0.954  Validation Accuracy: 0.747
# Epoch: 4/10  Training Loss: 0.965  Validation Loss: 1.004  Validation Accuracy: 0.740
# Epoch: 4/10  Training Loss: 1.603  Validation Loss: 1.006  Validation Accuracy: 0.722
# Epoch: 4/10  Training Loss: 1.625  Validation Loss: 0.938  Validation Accuracy: 0.735
# Epoch: 4/10  Training Loss: 1.534  Validation Loss: 0.938  Validation Accuracy: 0.752
# Epoch: 4/10  Training Loss: 1.644  Validation Loss: 0.940  Validation Accuracy: 0.739
# Epoch: 4/10  Training Loss: 1.473  Validation Loss: 0.934  Validation Accuracy: 0.744
# Epoch: 4/10  Training Loss: 1.628  Validation Loss: 0.905  Validation Accuracy: 0.752
# Epoch: 4/10  Training Loss: 1.507  Validation Loss: 0.847  Validation Accuracy: 0.771
# Epoch: 4/10  Training Loss: 1.472  Validation Loss: 0.905  Validation Accuracy: 0.749
# Epoch: 4/10  Training Loss: 1.659  Validation Loss: 0.978  Validation Accuracy: 0.741
# Epoch: 4/10  Training Loss: 1.645  Validation Loss: 0.994  Validation Accuracy: 0.739
# Epoch: 4/10  Training Loss: 1.618  Validation Loss: 0.922  Validation Accuracy: 0.760
# Epoch: 4/10  Training Loss: 1.670  Validation Loss: 0.841  Validation Accuracy: 0.770
# Epoch: 4/10  Training Loss: 1.581  Validation Loss: 0.783  Validation Accuracy: 0.777
# Epoch: 4/10  Training Loss: 1.511  Validation Loss: 0.778  Validation Accuracy: 0.792
# Epoch: 4/10  Training Loss: 1.575  Validation Loss: 0.880  Validation Accuracy: 0.762
# Epoch: 4/10  Training Loss: 1.554  Validation Loss: 0.901  Validation Accuracy: 0.753
# Epoch: 4/10  Training Loss: 1.639  Validation Loss: 0.939  Validation Accuracy: 0.753
# Epoch: 4/10  Training Loss: 1.586  Validation Loss: 0.852  Validation Accuracy: 0.783
# Epoch: 4/10  Training Loss: 1.398  Validation Loss: 0.857  Validation Accuracy: 0.780
# Epoch: 4/10  Training Loss: 1.346  Validation Loss: 0.939  Validation Accuracy: 0.754
# Epoch: 5/10  Training Loss: 0.905  Validation Loss: 0.909  Validation Accuracy: 0.750
# Epoch: 5/10  Training Loss: 1.480  Validation Loss: 0.873  Validation Accuracy: 0.772
# Epoch: 5/10  Training Loss: 1.409  Validation Loss: 0.823  Validation Accuracy: 0.773
# Epoch: 5/10  Training Loss: 1.415  Validation Loss: 0.845  Validation Accuracy: 0.792
# Epoch: 5/10  Training Loss: 1.538  Validation Loss: 0.915  Validation Accuracy: 0.755
# Epoch: 5/10  Training Loss: 1.717  Validation Loss: 0.900  Validation Accuracy: 0.775
# Epoch: 5/10  Training Loss: 1.472  Validation Loss: 0.869  Validation Accuracy: 0.779
# Epoch: 5/10  Training Loss: 1.530  Validation Loss: 0.858  Validation Accuracy: 0.767
# Epoch: 5/10  Training Loss: 1.628  Validation Loss: 0.912  Validation Accuracy: 0.761
# Epoch: 5/10  Training Loss: 1.415  Validation Loss: 0.869  Validation Accuracy: 0.778
# Epoch: 5/10  Training Loss: 1.382  Validation Loss: 0.833  Validation Accuracy: 0.780
# Epoch: 5/10  Training Loss: 1.385  Validation Loss: 0.901  Validation Accuracy: 0.778
# Epoch: 5/10  Training Loss: 1.574  Validation Loss: 0.843  Validation Accuracy: 0.776
# Epoch: 5/10  Training Loss: 1.386  Validation Loss: 0.900  Validation Accuracy: 0.756
# Epoch: 5/10  Training Loss: 1.482  Validation Loss: 0.857  Validation Accuracy: 0.785
# Epoch: 5/10  Training Loss: 1.600  Validation Loss: 0.907  Validation Accuracy: 0.773
# Epoch: 5/10  Training Loss: 1.682  Validation Loss: 0.872  Validation Accuracy: 0.769
# Epoch: 5/10  Training Loss: 1.418  Validation Loss: 0.886  Validation Accuracy: 0.779
# Epoch: 5/10  Training Loss: 1.456  Validation Loss: 0.843  Validation Accuracy: 0.772
# Epoch: 5/10  Training Loss: 1.523  Validation Loss: 0.801  Validation Accuracy: 0.789
# Epoch: 5/10  Training Loss: 1.423  Validation Loss: 0.808  Validation Accuracy: 0.792
# Epoch: 6/10  Training Loss: 0.788  Validation Loss: 0.789  Validation Accuracy: 0.797
# Epoch: 6/10  Training Loss: 1.268  Validation Loss: 0.865  Validation Accuracy: 0.778
# Epoch: 6/10  Training Loss: 1.313  Validation Loss: 0.790  Validation Accuracy: 0.791
# Epoch: 6/10  Training Loss: 1.354  Validation Loss: 0.764  Validation Accuracy: 0.801
# Epoch: 6/10  Training Loss: 1.540  Validation Loss: 0.837  Validation Accuracy: 0.782
# Epoch: 6/10  Training Loss: 1.420  Validation Loss: 0.838  Validation Accuracy: 0.765
# Epoch: 6/10  Training Loss: 1.364  Validation Loss: 0.813  Validation Accuracy: 0.778
# Epoch: 6/10  Training Loss: 1.468  Validation Loss: 0.835  Validation Accuracy: 0.773
# Epoch: 6/10  Training Loss: 1.671  Validation Loss: 0.776  Validation Accuracy: 0.783
# Epoch: 6/10  Training Loss: 1.380  Validation Loss: 0.713  Validation Accuracy: 0.806
# Epoch: 6/10  Training Loss: 1.548  Validation Loss: 0.782  Validation Accuracy: 0.788
# Epoch: 6/10  Training Loss: 1.344  Validation Loss: 0.815  Validation Accuracy: 0.785
# Epoch: 6/10  Training Loss: 1.446  Validation Loss: 0.770  Validation Accuracy: 0.794
# Epoch: 6/10  Training Loss: 1.381  Validation Loss: 0.691  Validation Accuracy: 0.805
# Epoch: 6/10  Training Loss: 1.333  Validation Loss: 0.746  Validation Accuracy: 0.803
# Epoch: 6/10  Training Loss: 1.482  Validation Loss: 0.767  Validation Accuracy: 0.795
# Epoch: 6/10  Training Loss: 1.644  Validation Loss: 0.770  Validation Accuracy: 0.781
# Epoch: 6/10  Training Loss: 1.503  Validation Loss: 0.814  Validation Accuracy: 0.800
# Epoch: 6/10  Training Loss: 1.509  Validation Loss: 0.725  Validation Accuracy: 0.817
# Epoch: 6/10  Training Loss: 1.506  Validation Loss: 0.760  Validation Accuracy: 0.802
# Epoch: 6/10  Training Loss: 1.489  Validation Loss: 0.764  Validation Accuracy: 0.802
# Epoch: 7/10  Training Loss: 0.636  Validation Loss: 0.769  Validation Accuracy: 0.798
# Epoch: 7/10  Training Loss: 1.208  Validation Loss: 0.784  Validation Accuracy: 0.799
# Epoch: 7/10  Training Loss: 1.581  Validation Loss: 0.767  Validation Accuracy: 0.796
# Epoch: 7/10  Training Loss: 1.177  Validation Loss: 0.800  Validation Accuracy: 0.786
# Epoch: 7/10  Training Loss: 1.412  Validation Loss: 0.798  Validation Accuracy: 0.792
# Epoch: 7/10  Training Loss: 1.408  Validation Loss: 0.773  Validation Accuracy: 0.797
# Epoch: 7/10  Training Loss: 1.612  Validation Loss: 0.743  Validation Accuracy: 0.808
# Epoch: 7/10  Training Loss: 1.362  Validation Loss: 0.774  Validation Accuracy: 0.818
# Epoch: 7/10  Training Loss: 1.312  Validation Loss: 0.694  Validation Accuracy: 0.818
# Epoch: 7/10  Training Loss: 1.336  Validation Loss: 0.738  Validation Accuracy: 0.806
# Epoch: 7/10  Training Loss: 1.400  Validation Loss: 0.814  Validation Accuracy: 0.792
# Epoch: 7/10  Training Loss: 1.458  Validation Loss: 0.739  Validation Accuracy: 0.806
# Epoch: 7/10  Training Loss: 1.392  Validation Loss: 0.709  Validation Accuracy: 0.815
# Epoch: 7/10  Training Loss: 1.334  Validation Loss: 0.805  Validation Accuracy: 0.796
# Epoch: 7/10  Training Loss: 1.612  Validation Loss: 0.738  Validation Accuracy: 0.825
# Epoch: 7/10  Training Loss: 1.304  Validation Loss: 0.685  Validation Accuracy: 0.818
# Epoch: 7/10  Training Loss: 1.558  Validation Loss: 0.670  Validation Accuracy: 0.830
# Epoch: 7/10  Training Loss: 1.479  Validation Loss: 0.700  Validation Accuracy: 0.826
# Epoch: 7/10  Training Loss: 1.348  Validation Loss: 0.730  Validation Accuracy: 0.819
# Epoch: 7/10  Training Loss: 1.310  Validation Loss: 0.753  Validation Accuracy: 0.820
# Epoch: 7/10  Training Loss: 1.379  Validation Loss: 0.843  Validation Accuracy: 0.794
# Epoch: 8/10  Training Loss: 0.725  Validation Loss: 0.789  Validation Accuracy: 0.802
# Epoch: 8/10  Training Loss: 1.543  Validation Loss: 0.711  Validation Accuracy: 0.825
# Epoch: 8/10  Training Loss: 1.394  Validation Loss: 0.674  Validation Accuracy: 0.823
# Epoch: 8/10  Training Loss: 1.263  Validation Loss: 0.709  Validation Accuracy: 0.821
# Epoch: 8/10  Training Loss: 1.342  Validation Loss: 0.746  Validation Accuracy: 0.806
# Epoch: 8/10  Training Loss: 1.287  Validation Loss: 0.691  Validation Accuracy: 0.818
# Epoch: 8/10  Training Loss: 1.448  Validation Loss: 0.707  Validation Accuracy: 0.819
# Epoch: 8/10  Training Loss: 1.614  Validation Loss: 0.731  Validation Accuracy: 0.814
# Epoch: 8/10  Training Loss: 1.434  Validation Loss: 0.677  Validation Accuracy: 0.823
# Epoch: 8/10  Training Loss: 1.428  Validation Loss: 0.653  Validation Accuracy: 0.820
# Epoch: 8/10  Training Loss: 1.478  Validation Loss: 0.668  Validation Accuracy: 0.823
# Epoch: 8/10  Training Loss: 1.505  Validation Loss: 0.672  Validation Accuracy: 0.824
# Epoch: 8/10  Training Loss: 1.263  Validation Loss: 0.677  Validation Accuracy: 0.841
# Epoch: 8/10  Training Loss: 1.369  Validation Loss: 0.706  Validation Accuracy: 0.815
# Epoch: 8/10  Training Loss: 1.537  Validation Loss: 0.737  Validation Accuracy: 0.820
# Epoch: 8/10  Training Loss: 1.419  Validation Loss: 0.787  Validation Accuracy: 0.809
# Epoch: 8/10  Training Loss: 1.607  Validation Loss: 0.755  Validation Accuracy: 0.818
# Epoch: 8/10  Training Loss: 1.295  Validation Loss: 0.659  Validation Accuracy: 0.839
# Epoch: 8/10  Training Loss: 1.505  Validation Loss: 0.653  Validation Accuracy: 0.828
# Epoch: 8/10  Training Loss: 1.132  Validation Loss: 0.659  Validation Accuracy: 0.827
# Epoch: 8/10  Training Loss: 1.335  Validation Loss: 0.656  Validation Accuracy: 0.836
# Epoch: 9/10  Training Loss: 0.623  Validation Loss: 0.690  Validation Accuracy: 0.829
# Epoch: 9/10  Training Loss: 1.212  Validation Loss: 0.687  Validation Accuracy: 0.833
# Epoch: 9/10  Training Loss: 1.456  Validation Loss: 0.637  Validation Accuracy: 0.834
# Epoch: 9/10  Training Loss: 1.328  Validation Loss: 0.689  Validation Accuracy: 0.819
# Epoch: 9/10  Training Loss: 1.254  Validation Loss: 0.788  Validation Accuracy: 0.808
# Epoch: 9/10  Training Loss: 1.297  Validation Loss: 0.671  Validation Accuracy: 0.830
# Epoch: 9/10  Training Loss: 1.390  Validation Loss: 0.630  Validation Accuracy: 0.831
# Epoch: 9/10  Training Loss: 1.391  Validation Loss: 0.745  Validation Accuracy: 0.808
# Epoch: 9/10  Training Loss: 1.324  Validation Loss: 0.828  Validation Accuracy: 0.798
# Epoch: 9/10  Training Loss: 1.638  Validation Loss: 0.846  Validation Accuracy: 0.784
# Epoch: 9/10  Training Loss: 1.450  Validation Loss: 0.772  Validation Accuracy: 0.807
# Epoch: 9/10  Training Loss: 1.666  Validation Loss: 0.822  Validation Accuracy: 0.792
# Epoch: 9/10  Training Loss: 1.443  Validation Loss: 0.656  Validation Accuracy: 0.833
# Epoch: 9/10  Training Loss: 1.276  Validation Loss: 0.643  Validation Accuracy: 0.829
# Epoch: 9/10  Training Loss: 1.240  Validation Loss: 0.654  Validation Accuracy: 0.825
# Epoch: 9/10  Training Loss: 1.315  Validation Loss: 0.672  Validation Accuracy: 0.818
# Epoch: 9/10  Training Loss: 1.355  Validation Loss: 0.782  Validation Accuracy: 0.807
# Epoch: 9/10  Training Loss: 1.389  Validation Loss: 0.740  Validation Accuracy: 0.819
# Epoch: 9/10  Training Loss: 1.307  Validation Loss: 0.777  Validation Accuracy: 0.806
# Epoch: 9/10  Training Loss: 1.613  Validation Loss: 0.740  Validation Accuracy: 0.811
# Epoch: 9/10  Training Loss: 1.352  Validation Loss: 0.723  Validation Accuracy: 0.823
# Epoch: 10/10  Training Loss: 0.697  Validation Loss: 0.720  Validation Accuracy: 0.832
# Epoch: 10/10  Training Loss: 1.194  Validation Loss: 0.727  Validation Accuracy: 0.824
# Epoch: 10/10  Training Loss: 1.189  Validation Loss: 0.696  Validation Accuracy: 0.829
# Epoch: 10/10  Training Loss: 1.320  Validation Loss: 0.714  Validation Accuracy: 0.823
# Epoch: 10/10  Training Loss: 1.320  Validation Loss: 0.666  Validation Accuracy: 0.837
# Epoch: 10/10  Training Loss: 1.294  Validation Loss: 0.760  Validation Accuracy: 0.813
# Epoch: 10/10  Training Loss: 1.514  Validation Loss: 0.786  Validation Accuracy: 0.800
# Epoch: 10/10  Training Loss: 1.214  Validation Loss: 0.776  Validation Accuracy: 0.795
# Epoch: 10/10  Training Loss: 1.525  Validation Loss: 0.756  Validation Accuracy: 0.828
# Epoch: 10/10  Training Loss: 1.554  Validation Loss: 0.696  Validation Accuracy: 0.817
# Epoch: 10/10  Training Loss: 1.397  Validation Loss: 0.686  Validation Accuracy: 0.836
# Epoch: 10/10  Training Loss: 1.448  Validation Loss: 0.644  Validation Accuracy: 0.828
# Epoch: 10/10  Training Loss: 1.300  Validation Loss: 0.665  Validation Accuracy: 0.843
# Epoch: 10/10  Training Loss: 1.374  Validation Loss: 0.775  Validation Accuracy: 0.815
# Epoch: 10/10  Training Loss: 1.472  Validation Loss: 0.738  Validation Accuracy: 0.808
# Epoch: 10/10  Training Loss: 1.283  Validation Loss: 0.710  Validation Accuracy: 0.830
# Epoch: 10/10  Training Loss: 1.284  Validation Loss: 0.708  Validation Accuracy: 0.833
# Epoch: 10/10  Training Loss: 1.343  Validation Loss: 0.652  Validation Accuracy: 0.837
# Epoch: 10/10  Training Loss: 1.309  Validation Loss: 0.637  Validation Accuracy: 0.836
# Epoch: 10/10  Training Loss: 1.220  Validation Loss: 0.625  Validation Accuracy: 0.838
# Epoch: 10/10  Training Loss: 1.295  Validation Loss: 0.644  Validation Accuracy: 0.845

# %%
# TODO: Do validation on the test set
correct = 0
total = 0
accuracy = 0
model.eval()
with torch.no_grad():
    for inputs, labels in validloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        total += labels.size(0)
        _, predicted = torch.max(outputs.data, 1)

        correct += (predicted == labels).sum().item()

       
        
        print("Accuracy is", correct/total*100)
# Out:
# Accuracy is 78.125
# Accuracy is 81.25
# Accuracy is 82.29166666666666
# Accuracy is 81.25
# Accuracy is 81.25
# Accuracy is 82.8125
# Accuracy is 82.14285714285714
# Accuracy is 82.421875
# Accuracy is 82.29166666666666
# Accuracy is 83.4375
# Accuracy is 84.6590909090909
# Accuracy is 85.41666666666666
# Accuracy is 85.57692307692307
# Accuracy is 85.49107142857143
# Accuracy is 85.20833333333333
# Accuracy is 84.9609375
# Accuracy is 84.19117647058823
# Accuracy is 83.85416666666666
# Accuracy is 84.04605263157895
# Accuracy is 83.59375
# Accuracy is 84.07738095238095
# Accuracy is 83.94886363636364
# Accuracy is 84.10326086956522
# Accuracy is 84.375
# Accuracy is 84.25
# Accuracy is 84.47432762836186

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
model.class_to_idx = train_data.class_to_idx
torch.save({'structure': 'vgg',
            'hidden_layer1': 364,
            'droupout': 0.5,
            'epochs': epochs,
            'model_state_dict': model.state_dict(),
            'class_to_idx': model.class_to_idx,
            'optimizer_dict': optimizer.state_dict()},
           'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
def load_model():
    weights = models.VGG19_Weights.DEFAULT
    model = models.vgg19(weights=weights)
    model.classifier = classifier()
    optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
    checkpoint = torch.load('checkpoint.pth')
    model.load_state_dict(checkpoint['model_state_dict'])
    model.class_to_idx = checkpoint['class_to_idx']
    optimizer.load_state_dict(checkpoint['optimizer_dict'])

    model.eval()
    return model, optimizer

model, optimizer = load_model()
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=4096, out_features=2048, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.5, inplace=False)
#     (fc3): Linear(in_features=2048, out_features=102, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    width, height = image.size
    
    if  width > height:
        image.thumbnail((width, 256))
    else:
        image.thumbnail((256, height))
    
    width, height = image.size
    left = (width - 224)/2
    bottom = (height - 224)/2
    right = left + 224
    top = bottom + 224

    crop_image=image.crop((left, bottom, right, top))
 
    np_image=np.array(crop_image)
    np_image=np_image.astype(np.float32)
    np_image=np_image/255
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225]) 
    new_image=(np_image-mean)/std
    
   
    procesed_image=new_image.transpose((2,0,1))
    
    return procesed_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

from PIL import Image
img_path = 'flowers/test/101/image_07952.jpg'
img = Image.open(img_path)
np_arr = process_image(img)
imshow(np_arr)
# Out:
# <Axes: >

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
model.class_to_idx
# Out:
# {'1': 0,
#  '10': 1,
#  '100': 2,
#  '101': 3,
#  '102': 4,
#  '11': 5,
#  '12': 6,
#  '13': 7,
#  '14': 8,
#  '15': 9,
#  '16': 10,
#  '17': 11,
#  '18': 12,
#  '19': 13,
#  '2': 14,
#  '20': 15,
#  '21': 16,
#  '22': 17,
#  '23': 18,
#  '24': 19,
#  '25': 20,
#  '26': 21,
#  '27': 22,
#  '28': 23,
#  '29': 24,
#  '3': 25,
#  '30': 26,
#  '31': 27,
#  '32': 28,
#  '33': 29,
#  '34': 30,
#  '35': 31,
#  '36': 32,
#  '37': 33,
#  '38': 34,
#  '39': 35,
#  '4': 36,
#  '40': 37,
#  '41': 38,
#  '42': 39,
#  '43': 40,
#  '44': 41,
#  '45': 42,
#  '46': 43,
#  '47': 44,
#  '48': 45,
#  '49': 46,
#  '5': 47,
#  '50': 48,
#  '51': 49,
#  '52': 50,
#  '53': 51,
#  '54': 52,
#  '55': 53,
#  '56': 54,
#  '57': 55,
#  '58': 56,
#  '59': 57,
#  '6': 58,
#  '60': 59,
#  '61': 60,
#  '62': 61,
#  '63': 62,
#  '64': 63,
#  '65': 64,
#  '66': 65,
#  '67': 66,
#  '68': 67,
#  '69': 68,
#  '7': 69,
#  '70': 70,
#  '71': 71,
#  '72': 72,
#  '73': 73,
#  '74': 74,
#  '75': 75,
#  '76': 76,
#  '77': 77,
#  '78': 78,
#  '79': 79,
#  '8': 80,
#  '80': 81,
#  '81': 82,
#  '82': 83,
#  '83': 84,
#  '84': 85,
#  '85': 86,
#  '86': 87,
#  '87': 88,
#  '88': 89,
#  '89': 90,
#  '9': 91,
#  '90': 92,
#  '91': 93,
#  '92': 94,
#  '93': 95,
#  '94': 96,
#  '95': 97,
#  '96': 98,
#  '97': 99,
#  '98': 100,
#  '99': 101}

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()
    img = Image.open(image_path)
    image_as_np = process_image(img)
    image = torch.from_numpy(image_as_np).type(torch.FloatTensor)
    image = image.unsqueeze(0)
    image = image.to(device)
    output = model.forward(image)
    exp = torch.exp(output)
    top_p, top_class = exp.topk(topk, dim=1)
    top_p = top_p.cpu()
    top_class = top_class.cpu()
    top_p = top_p.detach().numpy()
    top_class = top_class.detach().numpy()
    return top_p, top_class

predict(img_path, model, topk=5)
# Out:
# (array([[9.9996400e-01, 1.6189528e-05, 1.5726198e-05, 1.8325615e-06,
#          1.2783071e-06]], dtype=float32),
#  array([[  3,   5,  49, 100,  72]]))

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

def view_classify(img_path, model, topk=5):
    top_p, top_class = predict(img_path, model, topk)
    top_p = top_p[0]
    top_class = top_class[0]
    idx_to_class = {val: key for key, val in model.class_to_idx.items()}
    top_class = [idx_to_class[lab] for lab in top_class]
    top_flowers = [cat_to_name[lab] for lab in top_class]

    img = Image.open(img_path)
    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img)
    ax1.axis('off')
    print(top_p)
    ax2.barh(np.arange(topk), top_p)
    ax2.set_aspect(0.2)
    ax2.set_yticks(np.arange(topk))
    ax2.set_yticklabels(top_flowers, size='small');
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)
    plt.tight_layout()
    plt.show()


view_classify('flowers/test/35/image_07006.jpg', model, topk=5)
# Out:
# [1.0000000e+00 6.4006743e-15 7.0314438e-18 5.1838065e-20 1.5391786e-20]
